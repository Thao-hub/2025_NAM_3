# %%
# !pip install geopandas
# !pip install matplotlib

# %%
# Cài thư viện folium để sử dụng được bản đồ
# !pip install folium
# Cài thư viện mapclassify
# !pip install mapclassify

# %%
print ("Hello World")
print ("Hello World2")
# Out:
# Hello World
# Hello World2

# %%
msg = "Hello World"
print(msg)
# Out:
# Hello World

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
num_bins = 5
plt.hist(x, num_bins)
plt.show()

# %%
num_points = 150
coordinate_system = "WGS 84"
is_geo = True
coordinates = [32.6835, 129.6612]

print(num_points)
print(coordinate_system)
print(is_geo)
print(coordinates)
# Out:
# 150
# WGS 84
# True
# [32.6835, 129.6612]

# %%
feature_attributes = {
    "name":"Mount Fuji",
    "height_meters":3776,
    "type":"Stratovolcano",
    "location":[35.3606,138.7274],
}
#print(feature_attributes["name"])
print(feature_attributes)

mount_fuji_name = feature_attributes["name"]
mount_fuji_height = feature_attributes["height_meters"]
print(f"{mount_fuji_name} là {mount_fuji_height} mét")
# Out:
# {'name': 'Mount Fuji', 'height_meters': 3776, 'type': 'Stratovolcano', 'location': [35.3606, 138.7274]}
# Mount Fuji là 3776 mét

# %%
import math
latitude = 35.6895
latitude_radians = math.radians(latitude)
print("Vĩ độ theo đơn vị radian:",latitude_radians)
# Out:
# Vĩ độ theo đơn vị radian: 0.6228992833905163

# %%
coordinates = [35.6895, 139.6917] # Danh sách có sẵn
coordinates.append(34.0522) # Thêm vĩ độ mới
coordinates.append(-118.2437) # Thêm kinh độ mới
print("Danh sách tọa độ đã cập nhật:", coordinates)
# Out:
# Danh sách tọa độ đã cập nhật: [35.6895, 139.6917, 34.0522, -118.2437]

# %%
points = [
    [35.6895, 139.6917],
    [34.0522, -118.2437],
    [51.5074,-0.1278],
    [48.8566, 2.3522],
]
centroid_lat = sum([point[0] for point in points])/ len(points)
centroid_lon = sum([point[1] for point in points])/ len(points)
centroid = [centroid_lat, centroid_lon]
print("Tâm của các điểm là:", centroid)
# Out:
# Tâm của các điểm là: [42.526425, 5.918099999999998]

# %%
# Tuple
point = (
    35.6895,
    139.6917,
)
latitude = point[0]
longtitude = point[1]
print(f"Latitude:{latitude}, Longtitude:{longtitude}")
# Out:
# Latitude:35.6895, Longtitude:139.6917

# %%
# list
path = [
    (35.6895, 139.6917),
    (34.0522, -118.2437),
    (51.5074, -0.1278),
]
path.append((48.8566, 2.3522))
print("Path da duoc cap nha:", path)

# list(next)
sub_path = path[:2] 
print("Sub-path:", sub_path)
# Out:
# Path da duoc cap nha: [(35.6895, 139.6917), (34.0522, -118.2437), (51.5074, -0.1278), (48.8566, 2.3522)]
# Sub-path: [(35.6895, 139.6917), (34.0522, -118.2437)]

# %%
# Set
regions = ["North America", "Europe", "Asia"]
regions = set(regions)
# add new area
regions.add("Africa")
print("Khu vực được cập nhật:", regions)
# Out:
# Khu vực được cập nhật: {'Africa', 'Asia', 'North America', 'Europe'}

# %%
# Dictionary
city_attributes = {
    "name":"Tokyo",
    "population":"13929286",
    "coordinates":(35.6895, 139.6917),
}
city_name = city_attributes["name"]
city_population = city_attributes["population"]
print(f"City:{city_name}, Population:{city_population}")

# Dictionary (next)
city_attributes["area_km2"] = 2191
print("Thuộc tính của thành phố đã được cập nhật:", city_attributes)
# Out:
# City:Tokyo, Population:13929286
# Thuộc tính của thành phố đã được cập nhật: {'name': 'Tokyo', 'population': '13929286', 'coordinates': (35.6895, 139.6917), 'area_km2': 2191}

# %%
coordinates = [
    (35.6895, 139.6917),
    (34.0522, -118.2437),
    (51.5074, -0.1278),
]

for lat, lon in coordinates:
    print(f"Latitude: {lat}, Longitude: {lon}")
# Out:
# Latitude: 35.6895, Longitude: 139.6917
# Latitude: 34.0522, Longitude: -118.2437
# Latitude: 51.5074, Longitude: -0.1278

# %%
counter = 0
while counter < len(coordinates):
    lat, lon = coordinates[counter]
    print(f"Processing coordinate: ({lat}, {lon})")
    counter += 1
# Out:
# Processing coordinate: (35.6895, 139.6917)
# Processing coordinate: (34.0522, -118.2437)
# Processing coordinate: (51.5074, -0.1278)

# %%
def calculate_distance(lat1, lon1, lat2, lon2):
    return ((lat2 - lat1) ** 2 + (lon2 - lon1) ** 2) ** 0.5
reference_point = (0, 0)
for lat, lon in coordinates:
    distance = calculate_distance(reference_point[0], reference_point[1], lat, lon)
    print(f"Distance from {reference_point} to ({lat}, {lon}): {distance:.2f}")
# Out:
# Distance from (0, 0) to (35.6895, 139.6917): 144.18
# Distance from (0, 0) to (34.0522, -118.2437): 123.05
# Distance from (0, 0) to (51.5074, -0.1278): 51.51

# %%
for lat, lon in coordinates:
    if lat > 0:
        print(f"{lat} is in the Northern Hemisphere")
    elif lat < 0:
        print(f"{lat} is in the Southern Hemisphere")
    else:
        print(f"{lat} is near the equator")
# Out:
# 35.6895 is in the Northern Hemisphere
# 34.0522 is in the Northern Hemisphere
# 51.5074 is in the Northern Hemisphere

# %%
for lat, lon in coordinates:
    if lat > 0:
        hemisphere = "Northern"
    else:
        hemisphere = "Southern"
        
    if lon > 0:
        direction = "Eastern"
    else:
        direction = "Western"
        
    print(
        f"The coordinate ({lat}, {lon}) is in the {hemisphere} Hemisphere and {direction} Hemisphere."
    )
# Out:
# The coordinate (35.6895, 139.6917) is in the Northern Hemisphere and Eastern Hemisphere.
# The coordinate (34.0522, -118.2437) is in the Northern Hemisphere and Western Hemisphere.
# The coordinate (51.5074, -0.1278) is in the Northern Hemisphere and Western Hemisphere.

# %%
filtered_coordinates = []
for lat, lon in coordinates:
    if lon > 0:
        filtered_coordinates.append((lat, lon))
print(f"Filtered coordinates (only with positive longitude): {filtered_coordinates}")

southern_count = 0
for lat, lon in coordinates:
    if lat < 0:
        southern_count += 1
print(f"Number of coordinates in the Southern Hemisphere: {southern_count}")
# Out:
# Filtered coordinates (only with positive longitude): [(35.6895, 139.6917)]
# Number of coordinates in the Southern Hemisphere: 0

# %%
def average(*numbers):
    return sum(numbers) / len(numbers)

print(average(10, 20, 30))
print(average(5, 15, 25, 35))

def describe_point(latitude, longitude, **kwargs):
    description = f"Point at ({latitude}, {longitude})"
    for key, value in kwargs.items():
        description += f", {key}: {value}"
    
    return description
print(describe_point(35.6895, 139.6917, name="Tokyo", population=37400000))
print(describe_point(34.0522, -118.2437, name="Los Angeles", state="California"))
# Out:
# 20.0
# 20.0
# Point at (35.6895, 139.6917), name: Tokyo, population: 37400000
# Point at (34.0522, -118.2437), name: Los Angeles, state: California

# %%
class Point:
    def __init__(self, latitude, longitude, name=None):
        self.latitude = latitude
        self.longitude = longitude
        self.name = name
        
    def __str__(self):
        return f"{self.name or 'Point'} ({self.latitude}, {self.longitude})"

# %%
from math import radians, sin, cos, sqrt, atan2

def haversine(lat1, lon1, lat2, lon2, radius=6371.0):
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    
    a = (
        sin(dlat / 2) ** 2
        + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon / 2) ** 2
    )
    
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = radius * c
    return distance

# %%
class Point:
    def __init__(self, latitude, longitude, name=None):
        self.latitude = latitude
        self.longitude = longitude
        self.name = name
        
    def distance_to(self, other_point):
        return haversine(
            self.latitude, self.longitude, 
            other_point.latitude, other_point.longitude
        )

    def __str__(self):
        return f"{self.name or 'Point'} ({self.latitude}, {self.longitude})"

# %%
class Route:
    def __init__(self, points):
        self.points = points
        
    def total_distance(self):
        total_dist = 0
        for i in range(len(self.points) - 1):
            total_dist += self.points[i].distance_to(self.points[i + 1])
        return total_dist

# %%
class Point:

    def __init__(self, latitude, longitude, name=None):
        self.latitude = latitude
        self.longitude = longitude
        self.name = name

    def __str__(self):
        return f"{self.name or 'Point'} ({self.latitude}, {self.longitude})"

# %%
point1 = Point(35.6895, 139.6917, "Tokyo")
point2 = Point(34.0522, -118.2437, "Los Angeles")

print(
    f"Distance from {point1.name} to {point2.name}: "
    f"{point1.distance_to(point2):.2f} km"
)
# Out:
# Distance from Tokyo to Los Angeles: 8815.47 km

# %%
class Point:

    def __init__(self, latitude, longitude, name="Unnamed"):
        self.latitude = latitude
        self.longitude = longitude
        self.name = name

# %%
sample_data = """35.6895,139.6917
34.0522,-118.2437
51.5074,-0.1278
-33.8688,151.2093
48.8566,2.3522"""
output_file = "coordinates.txt"
try:
    with open(output_file, "w") as file:
        file.write(sample_data)
    print(f"Sample file '{output_file}' has been created successfully.")
except Exception as e:
    print(f"An error occurred while creating the file: {e}")
# Out:
# Sample file 'coordinates.txt' has been created successfully.

# %%
input_file = "coordinates.txt"
output_file = "output_coordinates.txt"
try:
    with open(input_file, "r") as infile:
        coordinates = infile.readlines()
    with open(output_file, "w") as outfile:
        for line in coordinates:
            lat, lon = line.strip().split(",")
            outfile.write(f"Latitude: {lat}, Longitude: {lon}\n")
    print(f"Tọa độ đã được ghi vào file {output_file}")
except FileNotFoundError:
    print(f"Lỗi: Tập tin {input_file} đã không tìm thấy.")
# Out:
# Tọa độ đã được ghi vào file output_coordinates.txt

# %%
def parse_coordinates(line):
    try:
        lat, lon = line.strip().split(",")
        lat = float(lat)
        lon = float(lon)
        return lat, lon
    except ValueError as e:
        print(f"Error: {e}. Could not parse line: {line.strip()}")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# %%
# Gọi hàm để kiểm tra ngoại lệ
line = "invalid data"
coordinates = parse_coordinates(line)
if coordinates:
    print(f"Parsed coordinates: {coordinates}")
# Out:
# Error: not enough values to unpack (expected 2, got 1). Could not parse line: invalid data

# %%
def process_geospatial_file(input_file):
    try:
        with open(input_file, "r") as infile:
            for line in infile:
                coordinates = parse_coordinates(line)
                if coordinates:
                    print(f"Processed coordinates: {coordinates}")
    except FileNotFoundError:
        print(f"Error: The file {input_file} was not found.")
    except Exception as e:
        print(f"An unexpected error occurred while processing the file: {e}")
    finally:
        print(f"Finished processing {input_file}")

# %%
# Gọi hàm
file_name = "coordinates.txt"
coordinates = process_geospatial_file(file_name)
# Out:
# Processed coordinates: (35.6895, 139.6917)
# Processed coordinates: (34.0522, -118.2437)
# Processed coordinates: (51.5074, -0.1278)
# Processed coordinates: (-33.8688, 151.2093)
# Processed coordinates: (48.8566, 2.3522)
# Finished processing coordinates.txt

# %%
import requests

url = "https://raw.githubusercontent.com/nvkelso/natural-earth-vector/master/geojson/ne_10m_populated_places.geojson"

def fetch_geojson(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raises an exception for HTTP errors
        geojson_data = response.json()  # Parse the JSON response
        return geojson_data
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")
    except requests.exceptions.ConnectionError as conn_err:
        print(f"Error connecting to the server: {conn_err}")
    except Exception as err:
        print(f"An error occurred: {err}")
    return None

# %%
geojson_data = fetch_geojson(url)

if geojson_data:
    features = geojson_data.get("features", [])
    print(f"Số thành phố: {len(features)}")

    for feature in features[:5]:
        props = feature.get("properties", {})
        city_name = props.get("name") or props.get("NAME")
        country_name = props.get("adm0name") or props.get("ADM0NAME")
        coordinates = feature["geometry"]["coordinates"]
        print(f"Tên: {city_name}, Quốc gia: {country_name}, Tọa độ: {coordinates}")
# Out:
# Số thành phố: 7342
# Tên: Colonia del Sacramento, Quốc gia: Uruguay, Tọa độ: [-57.836116, -34.469788]
# Tên: Trinidad, Quốc gia: Uruguay, Tọa độ: [-56.900997, -33.543999]
# Tên: Fray Bentos, Quốc gia: Uruguay, Tọa độ: [-58.303998, -33.138999]
# Tên: Canelones, Quốc gia: Uruguay, Tọa độ: [-56.284002, -34.538004]
# Tên: Florida, Quốc gia: Uruguay, Tọa độ: [-56.214998, -34.099002]
