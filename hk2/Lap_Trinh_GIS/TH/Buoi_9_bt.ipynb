# %%
# !pip install leafmap
# !pip install mapclassify
# !pip install matplotlib
# !pip install requests
# !pip install geopandas
# !pip install folium
# !pip install mapclassifys
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement mapclassifys (from versions: none)
# ERROR: No matching distribution found for mapclassifys
